# %% [markdown]
# <a href="https://colab.research.google.com/github/rumannaukhaiz/flyrank-ml-internship/blob/main/Copy_of_w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rumannaukhaiz/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/rumannaukhaiz/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane: Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because it addresses a real business problem: identifying which webpages should be reviewed first for content refresh. Large websites often contain thousands of pages, making manual review time-consuming and inefficient. By using observable search and engagement signals, a machine learning model can prioritize pages that are more likely to need attention, helping teams make faster and more informed decisions. I selected this lane because it combines data analysis, machine learning, and explainable decision support while providing practical experience with solving a real-world content optimization problem.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The goal of this project is to improve the decision of **which webpages should be reviewed first for content refresh**. The output will be a prioritized list of pages based on observable search and engagement signals. This ranking will help content or SEO teams decide where to focus their time and effort first. If the recommendation is wrong, the team may spend time reviewing low-priority pages while missing pages that actually need attention, leading to less effective use of resources and missed improvement opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ###  Quick Look at the Data (2–3 Real Numbers)
#
# The starter dataset contains **30,000** content pages. On average, each page has **5,200.37 impressions** and **37.07 sessions** over the last 90 days. These numbers show that the dataset contains meaningful search visibility and user engagement signals, making it suitable for developing a machine learning model that can rank webpages for content refresh and review. This supports my choice of the **Refresh / Content Opportunity Scoring** lane for the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset
df = pd.read_csv("flyrank-ml-internship/data/raw/content_refresh_anonymized.csv")

# Show 3 real numbers
print("Total pages:", len(df))
print("Average 90-day impressions:", round(df["impressions_90d"].mean(), 2))
print("Average 90-day sessions:", round(df["sessions_90d"].mean(), 2))
# Out:
# Total pages: 30000
# Average 90-day impressions: 5200.37
# Average 90-day sessions: 37.07

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ###  Careful Words: What I Can and Can't Claim
#
# This project identifies observed patterns in search and engagement data to support content review decisions. The machine learning model ranks webpages based on measurable signals, helping teams prioritize which pages should be reviewed first.
#
# This project cannot prove that refreshing a page will increase traffic or search rankings. It cannot predict Google's algorithms or establish cause-and-effect relationships. The recommendations are intended to support human decision-making, and final content decisions should always involve human judgment.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
